# %%
import numpy as np
import pandas as pd
from statsmodels.tsa.stattools import adfuller, kpss

# -----------------------------
# Example Time Series
# -----------------------------
# Creating non-stationary data (random walk)
np.random.seed(42)
n = 200

random_walk = np.cumsum(np.random.normal(size=n))

data = pd.Series(random_walk)

# -----------------------------
# ADF Test
# -----------------------------
print("===== ADF Test =====")

adf_result = adfuller(data)

print(f"ADF Statistic: {adf_result[0]}")
print(f"p-value: {adf_result[1]}")
print(f"Number of Lags Used: {adf_result[2]}")
print(f"Number of Observations: {adf_result[3]}")

print("Critical Values:")
for key, value in adf_result[4].items():
    print(f"   {key}: {value}")

if adf_result[1] < 0.05:
    print("Conclusion: Series is Stationary (Reject H0)")
else:
    print("Conclusion: Series is NOT Stationary (Fail to Reject H0)")


# -----------------------------
# KPSS Test
# -----------------------------
print("\n===== KPSS Test =====")

kpss_result = kpss(data, regression='c')  # 'c' = constant, 'ct' = constant + trend

print(f"KPSS Statistic: {kpss_result[0]}")
print(f"p-value: {kpss_result[1]}")
print(f"Lags Used: {kpss_result[2]}")

print("Critical Values:")
for key, value in kpss_result[3].items():
    print(f"   {key}: {value}")

if kpss_result[1] < 0.05:
    print("Conclusion: Series is NOT Stationary (Reject H0)")
else:
    print("Conclusion: Series is Stationary (Fail to Reject H0)")
# Out:
# ===== ADF Test =====
# ADF Statistic: -2.3072851790645257
# p-value: 0.1696291207894371
# Number of Lags Used: 0
# Number of Observations: 199
# Critical Values:
#    1%: -3.4636447617687436
#    5%: -2.8761761179270766
#    10%: -2.57457158581854
# Conclusion: Series is NOT Stationary (Fail to Reject H0)
#
# ===== KPSS Test =====
# KPSS Statistic: 0.7001396636588894
# p-value: 0.013532757849191876
# Lags Used: 9
# Critical Values:
#    10%: 0.347
#    5%: 0.463
#    2.5%: 0.574
#    1%: 0.739
# Conclusion: Series is NOT Stationary (Reject H0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# -----------------------------
# Generate Example Time Series
# (Non-stationary random walk)
# -----------------------------
np.random.seed(42)
n = 200
data = pd.Series(np.cumsum(np.random.normal(size=n)))

# -----------------------------
# 1. Original Time Series Plot
# -----------------------------
plt.figure()
plt.plot(data)
plt.title("Original Time Series")
plt.xlabel("Time")
plt.ylabel("Value")
plt.show()



# -----------------------------
# 2. ACF Plot
# -----------------------------
plt.figure()
plot_acf(data, lags=30)
plt.title("Autocorrelation Function (ACF)")
plt.show()


# -----------------------------
# 3. PACF Plot
# -----------------------------
plt.figure()
plot_pacf(data, lags=30, method='ywm')
plt.title("Partial Autocorrelation Function (PACF)")
plt.show()

# -----------------------------
# 4. Rolling Mean & Rolling Std
# -----------------------------
rolling_mean = data.rolling(window=12).mean()
rolling_std = data.rolling(window=12).std()

plt.figure()
plt.plot(data)
plt.plot(rolling_mean)
plt.plot(rolling_std)
plt.title("Rolling Mean and Rolling Standard Deviation")
plt.show()
